# %%
import gensim
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
import nltk
import pandas as pd
from gensim.parsing.preprocessing import remove_stopwords

# %% [markdown]
# Import and understand the data

# %%
#load data
data = pd.read_csv('./data/data-small-file.csv')
data_text['headline_text'] = data[['headline_text']]
data_text['index'] = data_text.index
documents = data_text
print(len(documents))
print(documents[:5])
# Out:
# 48
#                                        headline_text  index
# 0  win over cena satisfying but defeating underta...      0
# 1                                        Raju Chacha      1
# 2  Status quo will not be disturbed at Ayodhya; s...      2
# 3                Fissures in Hurriyat over Pak visit      3
# 4              America's unwanted heading for India?      4

# %%
stemmer = SnowballStemmer("english")

def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

doc_sample = documents[documents['index'] == 4].values[0][0]
words = []

for word in doc_sample.split(' '):
    words.append(word)
print(words)    
remove_stopwords(doc_sample)
print(doc_sample)
# Out:
# ["America's", 'unwanted', 'heading', 'for', 'India?']
# America's unwanted heading for India?
